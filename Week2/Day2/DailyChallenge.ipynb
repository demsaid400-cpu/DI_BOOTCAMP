# %% [markdown]
# <a href="https://colab.research.google.com/github/demsaid400-cpu/DI_BOOTCAMP/blob/main/DailyChallenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma", "Frank"],
    "Age": [5, 16, 25, 45, 70, 12]
}

df = pd.DataFrame(data)

bins = [0, 12, 18, 60, 100]
labels = ["Child", "Teen", "Adult", "Senior"]

df["Age_Group"] = pd.cut(df["Age"], bins=bins, labels=labels, right=True)

df_encoded = pd.get_dummies(df, columns=["Age_Group"])

print(df_encoded)
# Out:
#       Name  Age  Age_Group_Child  Age_Group_Teen  Age_Group_Adult  \
# 0    Alice    5             True           False            False
# 1      Bob   16            False            True            False
# 2  Charlie   25            False           False             True
# 3    David   45            False           False             True
# 4     Emma   70            False           False            False
# 5    Frank   12             True           False            False
#
#    Age_Group_Senior
# 0             False
# 1             False
# 2             False
# 3             False
# 4              True
# 5             False
